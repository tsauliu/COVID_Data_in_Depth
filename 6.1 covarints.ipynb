# %%
import json
import pandas as pd
js=json.load(open('OneTimeSource\EUClusters_data.json','r'))

# %%
df=pd.DataFrame(js['countries']['United Kingdom'])

# %%
l=list(df.columns)
l.remove('week')
l.remove('total_sequences')
d=pd.melt(df,id_vars=['week','total_sequences'],value_vars=l,var_name='variant',value_name='N')
d['per']=d['N']/d['total_sequences']
d['variant']=d['variant'].astype('str').str.replace('(','').str.replace(')','').str.replace(' ','')
d=d.merge(variants,on='variant',how='left')
d.loc[d['variant']=='recombinant','variant2']='recombinant'
pd.pivot_table(d,index='variant2',columns='week',values='per',aggfunc='mean').to_clipboard()
# variants
# Out:
# C:\Users\Leo\AppData\Local\Temp\ipykernel_16296\2313733075.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   d['variant']=d['variant'].astype('str').str.replace('(','').str.replace(')','').str.replace(' ','')

# %%
# variants=pd.read_clipboard()
# variants=variants.fillna('')
# variants['name']=variants['WHO']+' '+variants['Pango Lineage']
# variants=variants[['Nextstrain Clade','name']]
# variants.columns=['variant','variant2']
variants['variant']=variants['variant'].astype('str').str.replace('(','').str.replace(')','').str.replace(' ','')
variants
# Out:
# C:\Users\Leo\AppData\Local\Temp\ipykernel_16296\3320872504.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   variants['variant']=variants['variant'].astype('str').str.replace('(','').str.replace(')','').str.replace(' ','')
#         variant                   variant2
# 0   20IAlpha,V1            αAlpha B.1.1.7
# 1    20HBeta,V2             βBeta B.1.351
# 2   20JGamma,V3                γGamma P.1
# 3      21ADelta          δDelta B.1.617.2
# 4      21IDelta                    δDelta
# 5      21JDelta                    δDelta
# 6      21BKappa          κKappa B.1.617.1
# 7    21CEpsilon  εEpsilon B.1.427, B.1.429
# 8        21DEta              ηEta B.1.525
# 9       21FIota              ιIota B.1.526
# 10    21GLambda               λLambda C.37
# 11        21HMu                μMu B.1.621
# ...
