# %%
# https://weibo.com/u/1424710994

import warnings
warnings.simplefilter(action='ignore')

import pandas as pd
import numpy as np

# %%
df=pd.read_csv('infection.csv',sep=',', engine='python')
df = df.astype(str)
df=df.replace('nan','')
df
# Out:
#                   微博调查感染率 Unnamed: 1 12月27日N=5676人   Unnamed: 3 Unnamed: 4  \
# 0                      江西      43.1%                                 39.9%
# 1                      四川      15.1%                      64.6%
# 2                      河南      21.7%                      56.6%
# 3                     黑龙江      46.3%                      29.3%
# 4                      广东      41.4%                      31.6%      73.0%
# 5                      湖北      13.7%                      58.9%      72.6%
# 6                      安徽      41.7%                      30.2%      71.9%
# 7                      天津      28.6%                      42.9%      71.4%
# 8                      辽宁      21.1%                      50.0%      71.1%
# 9                      山东      37.0%                      33.9%      70.9%
# 10                     陕西      32.3%                      38.4%      70.7%
# 11                     浙江      54.3%                      16.3%      70.7%
# ...

# %%
df[df.columns[1:]].agg(''.join, axis=1)
# Out:
# 0                     43.1%39.9%83.0%
# 1                     15.1%64.6%79.7%
# 2                     21.7%56.6%78.3%
# 3                     46.3%29.3%75.6%
# 4                     41.4%31.6%73.0%
# 5                     13.7%58.9%72.6%
# 6                     41.7%30.2%71.9%
# 7                     28.6%42.9%71.4%
# 8                     21.1%50.0%71.1%
# 9                     37.0%33.9%70.9%
# 10               32.3%38.4%70.7%L 正阳率
# 11                 54.3%16.3%70.7%阳过率
# 12                    45.7%24.7%70.4%
# 13                    37.4%32.5%69.9%
# 14                    11.8%57.3%69.1%
# 15                22.9%44.3% 67.1%说明:
# 16              35.7%31.0% 66.7%数据来源于
# 17    10.6%56.1% 66.7%@数据化管理的 每日微博调查。
# 18            35.3%30.9% 66.2%因为是在微博的
# 19            40.3%23.5% 63.7%调查,所以会受
# 20      47.2%6.1%53.4%微博用户结构与 我的粉丝结构的
# 21                         15.3%52.5%
# 22                             @数据化管理
# dtype: object
